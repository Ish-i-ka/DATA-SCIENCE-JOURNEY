# %% [markdown]
# # Module: SQLite3 Assignments
# ## Lesson: SQLite3
# ### Assignment 1: Creating and Connecting to a Database
#
# 1. Write a Python function to create a new SQLite3 database named `test.db`.
# 2. Write a Python function to create a table named `employees` with columns `id` (integer), `name` (text), `age` (integer), and `department` (text) in the `test.db` database.
#
# ### Assignment 2: Inserting Data
#
# 1. Write a Python function to insert a new employee into the `employees` table.
# 2. Insert at least 5 different employees into the `employees` table.
#
# ### Assignment 3: Querying Data
#
# 1. Write a Python function to fetch and display all records from the `employees` table.
# 2. Write a Python function to fetch and display all employees from a specific department.
#
# ### Assignment 4: Updating Data
#
# 1. Write a Python function to update the department of an employee based on their `id`.
# 2. Update the department of at least 2 employees and display the updated records.
#
# ### Assignment 5: Deleting Data
#
# 1. Write a Python function to delete an employee from the `employees` table based on their `id`.
# 2. Delete at least 1 employee and display the remaining records.
#
# ### Assignment 6: Advanced Queries
#
# 1. Write a Python function to fetch and display employees older than a certain age.
# 2. Write a Python function to fetch and display employees whose names start with a specific letter.
#
# ### Assignment 7: Handling Transactions
#
# 1. Write a Python function to insert multiple employees into the `employees` table in a single transaction. Ensure that if any insertion fails, none of the insertions are committed.
# 2. Write a Python function to update the age of multiple employees in a single transaction. Ensure that if any update fails, none of the updates are committed.
#
# ### Assignment 8: Creating Relationships
#
# 1. Create a new table named `departments` with columns `id` (integer) and `name` (text).
# 2. Modify the `employees` table to include a foreign key referencing the `id` column in the `departments` table.
# 3. Write a Python function to insert data into both the `departments` and `employees` tables, ensuring referential integrity.
#
# ### Assignment 9: Indexing and Optimization
#
# 1. Create an index on the `name` column of the `employees` table.
# 2. Write a Python function to fetch and display all employees whose names start with a specific letter. Compare the performance with and without the index.
#
# ### Assignment 10: Backing Up and Restoring Data
#
# 1. Write a Python function to back up the `test.db` database to a file named `backup.db`.
# 2. Write a Python function to restore the `test.db` database from the `backup.db` file.

# %%
# Assignment 1: Creating and Connecting to a Database

import sqlite3
#1. Write a Python function to create a new SQLite3 database named `test.db`.
connection = sqlite3.connect('test.db')
connection

#2. Write a Python function to create a table named `employees` with columns `id` (integer), 
#       `name` (text), `age` (integer), and `department` (text) in the `test.db` database.

cursor = connection.cursor()
cursor.execute(''' 
create table if not exists employees(
    id integer primary key,
    name text not null,
    age integer,
    department text
)   
''')
connection.commit()
cursor.close()
connection.close()

# %%
# Assignment 2: Inserting Data
import sqlite3
#1. Write a Python function to insert a new employee into the `employees` table.
connection = sqlite3.connect('test.db')
cursor = connection.cursor()
cursor.execute('''
insert into employees(id,name,age,department)
values("4","Ishika Saha","20","Data Scientist")               
''')

#2. Insert at least 5 different employees into the `employees` table
test = [
    (1, 'Mithu Saha', 25, 'Data Scientist'),
    (2, 'Rahul Roy', 31, 'SDE'),
    (3, 'Bibek Dhara', 24, 'Web Developer'),
    (6, 'Soumi Singh', 29, 'Finance'),
    (5, 'Priya Das', 22, 'Cyber security')
]
cursor.executemany('''
insert into employees(id,name,age,department)
values(?,?,?,?)
''', test)


connection.commit()
cursor.close()
connection.close()

# %%
# Assignment 3: Querying Data

#1. Write a Python function to fetch and display all records from the `employees` table.
connection = sqlite3.connect('test.db')
cursor = connection.cursor()
cursor.execute('Select * from employees')
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# (1, 'Mithu Saha', 25, 'Data Scientist')
# (2, 'Rahul Roy', 31, 'SDE')
# (3, 'Bibek Dhara', 24, 'Web Developer')
# (4, 'Ishika Saha', 20, 'Data Scientist')
# (5, 'Priya Das', 22, 'Cyber security')
# (6, 'Soumi Singh', 29, 'Finance')

# %%
#2. Write a Python function to fetch and display all employees from a specific department.

cursor.execute('Select * from employees where department = "Data Scientist"')
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# (1, 'Mithu Saha', 25, 'Data Scientist')
# (4, 'Ishika Saha', 20, 'Data Scientist')

# %%
# Assignment 4: Updating Data

#1. Write a Python function to update the department of an employee based on their `id`.
cursor.execute('''
update employees
set department='Marketing'
where id = '41'               
''')

connection.commit()

#2. Update the department of at least 2 employees and display the updated records.
cursor.execute('''
update employees
set department='Associate'
where id = '1' or id= '2'
              
''')
connection.commit()

# %%
cursor.execute('Select * from employees')
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# (1, 'Mithu Saha', 25, 'Associate')
# (2, 'Rahul Roy', 31, 'Associate')
# (3, 'Bibek Dhara', 24, 'Web Developer')
# (4, 'Ishika Saha', 20, 'Data Scientist')
# (5, 'Priya Das', 22, 'Cyber security')
# (6, 'Soumi Singh', 29, 'Finance')

# %%
# Assignment 5: Deleting Data

#1. Write a Python function to delete an employee from the `employees` table based on their `id`.
cursor.execute('''
delete from employees
where id = '41'              
''')
connection.commit()

#2. Delete at least 1 employee and display the remaining records.
cursor.execute('Select * from employees')
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# (1, 'Mithu Saha', 25, 'Associate')
# (2, 'Rahul Roy', 31, 'Associate')
# (3, 'Bibek Dhara', 24, 'Web Developer')
# (4, 'Ishika Saha', 20, 'Data Scientist')
# (5, 'Priya Das', 22, 'Cyber security')
# (6, 'Soumi Singh', 29, 'Finance')
# (42, 'Ishika Saha', 20, 'Data Scientist')

# %%
# Assignment 6: Advanced Queries

#1. Write a Python function to fetch and display employees older than a certain age.
cursor.execute('''
select * from employees
where age > 20              
''')
connection.commit()
#cursor.execute('Select * from employees')
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# (1, 'Mithu Saha', 25, 'Associate')
# (2, 'Rahul Roy', 31, 'Associate')
# (3, 'Bibek Dhara', 24, 'Web Developer')
# (5, 'Priya Das', 22, 'Cyber security')
# (6, 'Soumi Singh', 29, 'Finance')

# %%
#2. Write a Python function to fetch and display employees whose names start with a specific letter.

def access(letter):
    connection = sqlite3.connect('test.db')
    cursor = connection.cursor()
    
    cursor.execute('SELECT * FROM employees WHERE name LIKE ?', (letter + '%',))
    records = cursor.fetchall()
    
    if records:
        for record in records:
            print(record)
    else:
        print(f"No employees found whose names start with '{letter}'.")
    
    connection.close()
    

letter = input('Enter the letter: ')
if letter:
    access(letter)
else:
    print("No letter entered.")
# Out:
# (1, 'Mithu Saha', 25, 'Associate')

# %%
# Assignment 7: Handling Transactions

import sqlite3
#1. Write a Python function to insert multiple employees into the `employees` table in a single transaction. 
# Ensure that if any insertion fails, none of the insertions are committed.

def insert_multiple_employee(emp_data):
    connection = sqlite3.connect('test.db')
    cursor = connection.cursor()
    try:
        cursor.executemany('insert into employees(id,name,age,department) values(?,?,?,?)',emp_data)
        connection.commit()
        print('Succesful')
    except Exception as e:
        connection.rollback()
        print(e)
    finally:
        connection.close()

emp_data = [
    (25,"Raj",23,"Finance"),
    (26,"mimi",25,"Finance"),
    (27,"Ratul",23,"Marketting")
]

insert_multiple_employee(emp_data)
# Out:
# UNIQUE constraint failed: employees.id

# %%
#2. Write a Python function to update the age of multiple employees in a single transaction. 
# Ensure that if any update fails, none of the updates are committed.

def update_age(update):
    connection = sqlite3.connect('test.db')
    cursor = connection.cursor()
    cursor.executemany('''update employees
                        set age = ?
                        where id = ?''',update)
    connection.commit()
    connection.close()

update_age([(20,1),(20,2),(20,3)])

# %%
connection = sqlite3.connect('test.db')
cursor = connection.cursor()
cursor.execute('select * from employees')
rows = cursor.fetchall()
for row in rows:
    print(row)
# Out:
# (1, 'Mithu Saha', 20, 'Associate')
# (2, 'Rahul Roy', 20, 'Associate')
# (3, 'Bibek Dhara', 20, 'Web Developer')
# (4, 'Ishika Saha', 20, 'Data Scientist')
# (5, 'Priya Das', 22, 'Cyber security')
# (6, 'Soumi Singh', 29, 'Finance')
# (25, 'Raj', 23, 'Finance')
# (26, 'mimi', 25, 'Finance')
# (27, 'Ratul', 23, 'Marketting')

# %%
# Assignment 8: Creating Relationships

#1. Create a new table named `departments` with columns `id` (integer) and `name` (text).

# %%
#2. Modify the `employees` table to include a foreign key referencing the `id` column in the `departments` table.

# %%
#3.Write a Python function to insert data into both the `departments` and `employees` tables, ensuring referential integrity.
